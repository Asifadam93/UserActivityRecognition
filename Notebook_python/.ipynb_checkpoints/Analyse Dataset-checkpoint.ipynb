# %%
# Librairies utiles
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from IPython.core.display import Image, display
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.grid_search import GridSearchCV
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
# importation du dataset et affichage
activity_dataset = pd.read_csv("./dataset_fabien.csv")
activity_dataset.head(3)
# Out:
#               Action   Lieux        x1        x2        x3        x4  \
# 0  Se lever (chaise)  Maison  0.635193  0.562164  0.283249  0.328735
# 1  S'assoir (chaise)  Maison -0.049545  0.103683  0.085724 -0.032791
# 2  Se lever (chaise)  Maison  0.297607 -0.080673  0.219788  0.309570
#
#          x5        x6        x7        x8    ...            t11        t12  \
# 0  0.045013 -1.713516 -2.079834 -0.962936    ...      13.759354   9.239090
# 1  0.163528  0.037842  0.217407  0.337112    ...      14.849915  13.742599
# 2  0.875809  1.343872  1.078110  1.118820    ...      11.233459  10.096222
#
#          t13        t14        t15        t16        t17        t18  \
# 0   9.309723   8.747101   9.652100   9.859192  10.802505  13.584579
# 1  14.701477  15.057007  14.237000  14.550629  14.302826  17.004684
# 2  10.937775  12.562241  13.444504  14.579376  14.591339  13.250595
#
#          t19        t20
# 0  12.082214  14.362686
# 1  14.766113  14.721832
# 2  13.529510  13.901810
#
# ...

# %%
# récupération des dummies pour les Lieux
activity_dataset = pd.get_dummies(activity_dataset, columns=['Lieux'])
activity_dataset.head(3)
# Out:
#               Action        x1        x2        x3        x4        x5  \
# 0  Se lever (chaise)  0.635193  0.562164  0.283249  0.328735  0.045013
# 1  S'assoir (chaise) -0.049545  0.103683  0.085724 -0.032791  0.163528
# 2  Se lever (chaise)  0.297607 -0.080673  0.219788  0.309570  0.875809
#
#          x6        x7        x8        x9      ...             t14        t15  \
# 0 -1.713516 -2.079834 -0.962936 -2.556274      ...        8.747101   9.652100
# 1  0.037842  0.217407  0.337112  0.559769      ...       15.057007  14.237000
# 2  1.343872  1.078110  1.118820  0.959610      ...       12.562241  13.444504
#
#          t16        t17        t18        t19        t20  Lieux_Ecole  \
# 0   9.859192  10.802505  13.584579  12.082214  14.362686            0
# 1  14.550629  14.302826  17.004684  14.766113  14.721832            0
# 2  14.579376  14.591339  13.250595  13.529510  13.901810            0
#
#    Lieux_Exterieur  Lieux_Maison
# 0                0             1
# ...

# %%
# Liste des colonnes de notre dataset
activity_dataset.columns
# Out:
# Index(['Action', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',
#        'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20',
#        'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10', 'y11',
#        'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y20', 'z1',
#        'z2', 'z3', 'z4', 'z5', 'z6', 'z7', 'z8', 'z9', 'z10', 'z11', 'z12',
#        'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z20', 't1', 't2',
#        't3', 't4', 't5', 't6', 't7', 't8', 't9', 't10', 't11', 't12', 't13',
#        't14', 't15', 't16', 't17', 't18', 't19', 't20', 'Lieux_Ecole',
#        'Lieux_Exterieur', 'Lieux_Maison'],
#       dtype='object')

# %%
# Liste des colonnes sources et cibles
colonnes_source = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',
       'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20',
       'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10', 'y11',
       'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y20', 'z1',
       'z2', 'z3', 'z4', 'z5', 'z6', 'z7', 'z8', 'z9', 'z10', 'z11', 'z12',
       'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z20', 't1', 't2',
       't3', 't4', 't5', 't6', 't7', 't8', 't9', 't10', 't11', 't12', 't13',
       't14', 't15', 't16', 't17', 't18', 't19', 't20', 'Lieux_Ecole',
       'Lieux_Exterieur', 'Lieux_Maison']
colonnes_cible = ['Action']

# récupération des données correspondant aux colonnes 
source = activity_dataset[colonnes_source]
cible = activity_dataset[colonnes_cible]

# %%
# cration d'un jeu de données de test et d'entrainement
source_train, source_test, cible_train, cible_test = train_test_split(source, cible, test_size=0.7)

# %%
#[print('classe ',i,' : ',sum(cible_train==i)) for i in cible_train.values]

pd.Series.value_counts(activity_dataset['Action'])
# Out:
# Se lever (chaise)                      49
# Se lever (depuis position allongée)    49
# S'assoir (chaise)                      48
# Sauter                                 46
# Marcher                                45
# Ne rien faire                          45
# S'allonger (depuis position debout)    44
# Courrir                                44
# S'allonger (depuis position assise)    41
# S'assoir (depuis position allongée)    34
# Name: Action, dtype: int64

# %%
clf = DecisionTreeClassifier(max_depth=None).fit(source_train, cible_train)

with open("tree.dot", 'w') as f:
        export_graphviz(clf, out_file=f,
                        feature_names=colonnes_source,
                        filled=True)

# !dot -Tpng tree.dot -o tree.png 
display(Image('tree.png'))
